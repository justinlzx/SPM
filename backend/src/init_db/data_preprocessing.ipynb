# %%
# load data from csv 

import pandas as pd 

df = pd.read_csv('employee.csv')

df
# Out:
#      Staff_ID Staff_FName Staff_LName         Dept       Position    Country  \
# 0      130002        Jack         Sim          CEO             MD  Singapore
# 1      140001       Derek         Tan        Sales       Director  Singapore
# 2      150008        Eric         Loh  Solutioning       Director  Singapore
# 3      151408      Philip         Lee  Engineering       Director  Singapore
# 4      140894       Rahim      Khalid        Sales  Sales Manager  Singapore
# ..        ...         ...         ...          ...            ...        ...
# 549    210040       Trong      Nguyen           IT        IT Team  Singapore
# 550    210041        Seng        Saon           IT        IT Team  Singapore
# 551    210042       Naron     Savoeun           IT        IT Team  Singapore
# 552    210043        Phuc        Luon           IT        IT Team  Singapore
# 553    210044    Chandara       Tithe           IT        IT Team  Singapore
#
# ...

# %% [markdown]
# ### Get employee IDs

# %%
employee_ids = df['Staff_ID']

employee_ids.to_list()
# Out:
# [130002,
#  140001,
#  150008,
#  151408,
#  140894,
#  140002,
#  140003,
#  140004,
#  140015,
#  140025,
#  140036,
#  140078,
#  140102,
#  140108,
#  140115,
#  140525,
#  140736,
#  140878,
#  140880,
#  140881,
#  140882,
#  140883,
#  140886,
#  140887,
#  140888,
#  140889,
#  140890,
#  140891,
#  140892,
#  140893,
#  140895,
#  140898,
#  140900,
#  140901,
#  140940,
#  140941,
#  140942,
#  140945,
#  140947,
#  140948,
#  140008,
#  140927,
#  140928,
#  140929,
#  140933,
#  140934,
#  140935,
#  140937,
#  140938,
#  140103,
#  140910,
#  140911,
#  140912,
#  140917,
#  140918,
#  140919,
#  140879,
#  140903,
#  140904,
#  140905,
#  140908,
#  140909,
#  140944,
#  140923,
#  140924,
#  140925,
#  140926,
#  150143,
#  150065,
#  150075,
#  150076,
#  150085,
#  150095,
#  150096,
#  150115,
#  150118,
#  150125,
#  150126,
#  150138,
#  150142,
#  150245,
#  150148,
#  150155,
#  150162,
#  150163,
#  150165,
#  150166,
#  150168,
#  150175,
#  150192,
# ...
